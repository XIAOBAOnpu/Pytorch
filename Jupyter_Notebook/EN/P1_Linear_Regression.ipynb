# %% [markdown]
# ## Linear Regression

# %% [markdown]
# I make this part as the starting point of the Pytorch learning. (Fine, actually not me, but the up from BiliBili...)
# Since this is the first part, let's make it straightforwar ->: assuming a simple linear model as belo:w
#
# $$
# y = 3x
# $$
#
# Then let's iterate over the weight, from 0 to 5 in this case, and calculate the total differences between the true output and the estimated one.
# The last step of this part is to obtain the MSE (Mean Squared Error) by dividing the total squared difference by the number of samples, then plotting the results to visually identify the optimalweight.
# ye

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: define the model:

# %%
# Define our linear model in here:
class LinearModel:
    def __init__(self, weight):
        self.weight = weight

    def forward(self, input_x):
        return input_x * self.weight

    def loss_function(self, input_x, true_output_y):
        
        # get the predicted output using an ASSIGNED weight
        output_prediction = self.forward(input_x)
        
        # calculate the differences between true output and predicted output
        return (output_prediction - true_output_y) ** 2

# %% [markdown]
# And let's do some more pre-work here:

# %%
# Training set
x = np.arange(1.0, 10.0, 1.0)
y = 3 * x

# Initialize some data for plotting
weight_list = []
mse_list = []

# %% [markdown]
# ### Step 2: Iteration over different weight and get the MSE:

# %%
# Try different weight and iterate -> in order to find the opt weight
for weight in np.arange(0.0, 5.1, 0.1):
    print('=======================')
    print('Weight = ', weight)
    
    # Print headers with proper formatting
    print(f"{'True input':>12} {'Pred output':>12} {'True output':>12} {'Loss':>12}")

    # Put 1 weight into the model
    model = LinearModel(weight)
    loss_sum = 0
    
    # for each weight, calculate the total loss
    for x_validation, y_validation in zip(x, y):
        
        # Get the loss here
        loss_validation = model.loss_function(input_x = x_validation, true_output_y = y_validation)
        loss_sum += loss_validation
        
        y_predict = model.forward(input_x = x_validation)
        
        # Print the values for each iteration with proper formatting
        print(f"{x_validation:12.2f} {y_predict:12.2f} {y_validation:12.2f} {loss_validation:12.4f}")
        
    mse = loss_sum / len(x)
    print('MSE = ', mse)
    weight_list.append(weight)
    mse_list.append(mse)
# Out:
# =======================
# Weight =  0.0
#   True input  Pred output  True output         Loss
#         1.00         0.00         3.00       9.0000
#         2.00         0.00         6.00      36.0000
#         3.00         0.00         9.00      81.0000
#         4.00         0.00        12.00     144.0000
#         5.00         0.00        15.00     225.0000
#         6.00         0.00        18.00     324.0000
#         7.00         0.00        21.00     441.0000
#         8.00         0.00        24.00     576.0000
#         9.00         0.00        27.00     729.0000
# MSE =  285.0
# =======================
# Weight =  0.1
#   True input  Pred output  True output         Loss
#         1.00         0.10         3.00       8.4100
#         2.00         0.20         6.00      33.6400
#         3.00         0.30         9.00      75.6900
#         4.00         0.40        12.00     134.5600
#         5.00         0.50        15.00     210.2500
#         6.00         0.60        18.00     302.7600
#         7.00         0.70        21.00     412.0900
#         8.00         0.80        24.00     538.2400
#         9.00         0.90        27.00     681.2100
# MSE =  266.3166666666667
# =======================
# Weight =  0.2
#   True input  Pred output  True output         Loss
#         1.00         0.20         3.00       7.8400
#         2.00         0.40         6.00      31.3600
#         3.00         0.60         9.00      70.5600
#         4.00         0.80        12.00     125.4400
#         5.00         1.00        15.00     196.0000
#         6.00         1.20        18.00     282.2400
#         7.00         1.40        21.00     384.1600
#         8.00         1.60        24.00     501.7600
#         9.00         1.80        27.00     635.0400
# MSE =  248.26666666666668
# =======================
# Weight =  0.30000000000000004
#   True input  Pred output  True output         Loss
#         1.00         0.30         3.00       7.2900
#         2.00         0.60         6.00      29.1600
#         3.00         0.90         9.00      65.6100
#         4.00         1.20        12.00     116.6400
#         5.00         1.50        15.00     182.2500
#         6.00         1.80        18.00     262.4400
#         7.00         2.10        21.00     357.2100
#         8.00         2.40        24.00     466.5600
#         9.00         2.70        27.00     590.4900
# MSE =  230.85000000000002
# =======================
# Weight =  0.4
#   True input  Pred output  True output         Loss
#         1.00         0.40         3.00       6.7600
#         2.00         0.80         6.00      27.0400
#         3.00         1.20         9.00      60.8400
#         4.00         1.60        12.00     108.1600
#         5.00         2.00        15.00     169.0000
#         6.00         2.40        18.00     243.3600
#         7.00         2.80        21.00     331.2400
#         8.00         3.20        24.00     432.6400
#         9.00         3.60        27.00     547.5600
# MSE =  214.06666666666666
# =======================
# Weight =  0.5
#   True input  Pred output  True output         Loss
#         1.00         0.50         3.00       6.2500
#         2.00         1.00         6.00      25.0000
#         3.00         1.50         9.00      56.2500
#         4.00         2.00        12.00     100.0000
#         5.00         2.50        15.00     156.2500
#         6.00         3.00        18.00     225.0000
#         7.00         3.50        21.00     306.2500
#         8.00         4.00        24.00     400.0000
#         9.00         4.50        27.00     506.2500
# MSE =  197.91666666666666
# =======================
# Weight =  0.6000000000000001
#   True input  Pred output  True output         Loss
#         1.00         0.60         3.00       5.7600
#         2.00         1.20         6.00      23.0400
#         3.00         1.80         9.00      51.8400
#         4.00         2.40        12.00      92.1600
#         5.00         3.00        15.00     144.0000
#         6.00         3.60        18.00     207.3600
#         7.00         4.20        21.00     282.2400
#         8.00         4.80        24.00     368.6400
#         9.00         5.40        27.00     466.5600
# MSE =  182.39999999999998
# =======================
# Weight =  0.7000000000000001
#   True input  Pred output  True output         Loss
#         1.00         0.70         3.00       5.2900
#         2.00         1.40         6.00      21.1600
#         3.00         2.10         9.00      47.6100
#         4.00         2.80        12.00      84.6400
#         5.00         3.50        15.00     132.2500
#         6.00         4.20        18.00     190.4400
#         7.00         4.90        21.00     259.2100
#         8.00         5.60        24.00     338.5600
#         9.00         6.30        27.00     428.4900
# MSE =  167.51666666666665
# =======================
# Weight =  0.8
#   True input  Pred output  True output         Loss
#         1.00         0.80         3.00       4.8400
#         2.00         1.60         6.00      19.3600
#         3.00         2.40         9.00      43.5600
#         4.00         3.20        12.00      77.4400
#         5.00         4.00        15.00     121.0000
#         6.00         4.80        18.00     174.2400
#         7.00         5.60        21.00     237.1600
#         8.00         6.40        24.00     309.7600
#         9.00         7.20        27.00     392.0400
# MSE =  153.26666666666665
# =======================
# Weight =  0.9
#   True input  Pred output  True output         Loss
#         1.00         0.90         3.00       4.4100
#         2.00         1.80         6.00      17.6400
#         3.00         2.70         9.00      39.6900
#         4.00         3.60        12.00      70.5600
#         5.00         4.50        15.00     110.2500
#         6.00         5.40        18.00     158.7600
#         7.00         6.30        21.00     216.0900
#         8.00         7.20        24.00     282.2400
#         9.00         8.10        27.00     357.2100
# MSE =  139.64999999999998
# =======================
# Weight =  1.0
#   True input  Pred output  True output         Loss
#         1.00         1.00         3.00       4.0000
#         2.00         2.00         6.00      16.0000
#         3.00         3.00         9.00      36.0000
#         4.00         4.00        12.00      64.0000
#         5.00         5.00        15.00     100.0000
#         6.00         6.00        18.00     144.0000
#         7.00         7.00        21.00     196.0000
#         8.00         8.00        24.00     256.0000
#         9.00         9.00        27.00     324.0000
# MSE =  126.66666666666667
# =======================
# Weight =  1.1
#   True input  Pred output  True output         Loss
#         1.00         1.10         3.00       3.6100
#         2.00         2.20         6.00      14.4400
#         3.00         3.30         9.00      32.4900
#         4.00         4.40        12.00      57.7600
#         5.00         5.50        15.00      90.2500
#         6.00         6.60        18.00     129.9600
#         7.00         7.70        21.00     176.8900
#         8.00         8.80        24.00     231.0400
#         9.00         9.90        27.00     292.4100
# MSE =  114.31666666666666
# =======================
# Weight =  1.2000000000000002
#   True input  Pred output  True output         Loss
#         1.00         1.20         3.00       3.2400
#         2.00         2.40         6.00      12.9600
#         3.00         3.60         9.00      29.1600
#         4.00         4.80        12.00      51.8400
#         5.00         6.00        15.00      81.0000
#         6.00         7.20        18.00     116.6400
#         7.00         8.40        21.00     158.7600
#         8.00         9.60        24.00     207.3600
#         9.00        10.80        27.00     262.4400
# MSE =  102.59999999999998
# =======================
# Weight =  1.3
#   True input  Pred output  True output         Loss
#         1.00         1.30         3.00       2.8900
#         2.00         2.60         6.00      11.5600
#         3.00         3.90         9.00      26.0100
#         4.00         5.20        12.00      46.2400
#         5.00         6.50        15.00      72.2500
#         6.00         7.80        18.00     104.0400
#         7.00         9.10        21.00     141.6100
#         8.00        10.40        24.00     184.9600
#         9.00        11.70        27.00     234.0900
# MSE =  91.51666666666665
# =======================
# Weight =  1.4000000000000001
#   True input  Pred output  True output         Loss
#         1.00         1.40         3.00       2.5600
#         2.00         2.80         6.00      10.2400
#         3.00         4.20         9.00      23.0400
#         4.00         5.60        12.00      40.9600
#         5.00         7.00        15.00      64.0000
#         6.00         8.40        18.00      92.1600
#         7.00         9.80        21.00     125.4400
#         8.00        11.20        24.00     163.8400
#         9.00        12.60        27.00     207.3600
# MSE =  81.06666666666666
# =======================
# Weight =  1.5
#   True input  Pred output  True output         Loss
#         1.00         1.50         3.00       2.2500
#         2.00         3.00         6.00       9.0000
#         3.00         4.50         9.00      20.2500
#         4.00         6.00        12.00      36.0000
#         5.00         7.50        15.00      56.2500
#         6.00         9.00        18.00      81.0000
#         7.00        10.50        21.00     110.2500
#         8.00        12.00        24.00     144.0000
#         9.00        13.50        27.00     182.2500
# MSE =  71.25
# =======================
# Weight =  1.6
#   True input  Pred output  True output         Loss
#         1.00         1.60         3.00       1.9600
#         2.00         3.20         6.00       7.8400
#         3.00         4.80         9.00      17.6400
#         4.00         6.40        12.00      31.3600
#         5.00         8.00        15.00      49.0000
#         6.00         9.60        18.00      70.5600
#         7.00        11.20        21.00      96.0400
#         8.00        12.80        24.00     125.4400
#         9.00        14.40        27.00     158.7600
# MSE =  62.066666666666656
# =======================
# Weight =  1.7000000000000002
#   True input  Pred output  True output         Loss
#         1.00         1.70         3.00       1.6900
#         2.00         3.40         6.00       6.7600
#         3.00         5.10         9.00      15.2100
#         4.00         6.80        12.00      27.0400
#         5.00         8.50        15.00      42.2500
#         6.00        10.20        18.00      60.8400
#         7.00        11.90        21.00      82.8100
#         8.00        13.60        24.00     108.1600
#         9.00        15.30        27.00     136.8900
# MSE =  53.51666666666665
# =======================
# Weight =  1.8
#   True input  Pred output  True output         Loss
#         1.00         1.80         3.00       1.4400
#         2.00         3.60         6.00       5.7600
#         3.00         5.40         9.00      12.9600
#         4.00         7.20        12.00      23.0400
#         5.00         9.00        15.00      36.0000
#         6.00        10.80        18.00      51.8400
#         7.00        12.60        21.00      70.5600
#         8.00        14.40        24.00      92.1600
#         9.00        16.20        27.00     116.6400
# MSE =  45.599999999999994
# =======================
# Weight =  1.9000000000000001
#   True input  Pred output  True output         Loss
#         1.00         1.90         3.00       1.2100
#         2.00         3.80         6.00       4.8400
#         3.00         5.70         9.00      10.8900
#         4.00         7.60        12.00      19.3600
#         5.00         9.50        15.00      30.2500
#         6.00        11.40        18.00      43.5600
#         7.00        13.30        21.00      59.2900
#         8.00        15.20        24.00      77.4400
#         9.00        17.10        27.00      98.0100
# MSE =  38.31666666666666
# =======================
# Weight =  2.0
#   True input  Pred output  True output         Loss
#         1.00         2.00         3.00       1.0000
#         2.00         4.00         6.00       4.0000
#         3.00         6.00         9.00       9.0000
#         4.00         8.00        12.00      16.0000
#         5.00        10.00        15.00      25.0000
#         6.00        12.00        18.00      36.0000
#         7.00        14.00        21.00      49.0000
#         8.00        16.00        24.00      64.0000
#         9.00        18.00        27.00      81.0000
# MSE =  31.666666666666668
# =======================
# Weight =  2.1
#   True input  Pred output  True output         Loss
#         1.00         2.10         3.00       0.8100
#         2.00         4.20         6.00       3.2400
#         3.00         6.30         9.00       7.2900
#         4.00         8.40        12.00      12.9600
#         5.00        10.50        15.00      20.2500
#         6.00        12.60        18.00      29.1600
#         7.00        14.70        21.00      39.6900
#         8.00        16.80        24.00      51.8400
#         9.00        18.90        27.00      65.6100
# MSE =  25.64999999999999
# =======================
# Weight =  2.2
#   True input  Pred output  True output         Loss
#         1.00         2.20         3.00       0.6400
#         2.00         4.40         6.00       2.5600
#         3.00         6.60         9.00       5.7600
#         4.00         8.80        12.00      10.2400
#         5.00        11.00        15.00      16.0000
#         6.00        13.20        18.00      23.0400
#         7.00        15.40        21.00      31.3600
#         8.00        17.60        24.00      40.9600
#         9.00        19.80        27.00      51.8400
# MSE =  20.26666666666666
# =======================
# Weight =  2.3000000000000003
#   True input  Pred output  True output         Loss
#         1.00         2.30         3.00       0.4900
#         2.00         4.60         6.00       1.9600
#         3.00         6.90         9.00       4.4100
#         4.00         9.20        12.00       7.8400
#         5.00        11.50        15.00      12.2500
#         6.00        13.80        18.00      17.6400
#         7.00        16.10        21.00      24.0100
#         8.00        18.40        24.00      31.3600
#         9.00        20.70        27.00      39.6900
# MSE =  15.516666666666655
# =======================
# Weight =  2.4000000000000004
#   True input  Pred output  True output         Loss
#         1.00         2.40         3.00       0.3600
#         2.00         4.80         6.00       1.4400
#         3.00         7.20         9.00       3.2400
#         4.00         9.60        12.00       5.7600
#         5.00        12.00        15.00       9.0000
#         6.00        14.40        18.00      12.9600
#         7.00        16.80        21.00      17.6400
#         8.00        19.20        24.00      23.0400
#         9.00        21.60        27.00      29.1600
# MSE =  11.399999999999986
# =======================
# Weight =  2.5
#   True input  Pred output  True output         Loss
#         1.00         2.50         3.00       0.2500
#         2.00         5.00         6.00       1.0000
#         3.00         7.50         9.00       2.2500
#         4.00        10.00        12.00       4.0000
#         5.00        12.50        15.00       6.2500
#         6.00        15.00        18.00       9.0000
#         7.00        17.50        21.00      12.2500
#         8.00        20.00        24.00      16.0000
#         9.00        22.50        27.00      20.2500
# MSE =  7.916666666666667
# =======================
# Weight =  2.6
#   True input  Pred output  True output         Loss
#         1.00         2.60         3.00       0.1600
#         2.00         5.20         6.00       0.6400
#         3.00         7.80         9.00       1.4400
#         4.00        10.40        12.00       2.5600
#         5.00        13.00        15.00       4.0000
#         6.00        15.60        18.00       5.7600
#         7.00        18.20        21.00       7.8400
#         8.00        20.80        24.00      10.2400
#         9.00        23.40        27.00      12.9600
# MSE =  5.066666666666664
# =======================
# Weight =  2.7
#   True input  Pred output  True output         Loss
#         1.00         2.70         3.00       0.0900
#         2.00         5.40         6.00       0.3600
#         3.00         8.10         9.00       0.8100
#         4.00        10.80        12.00       1.4400
#         5.00        13.50        15.00       2.2500
#         6.00        16.20        18.00       3.2400
#         7.00        18.90        21.00       4.4100
#         8.00        21.60        24.00       5.7600
#         9.00        24.30        27.00       7.2900
# MSE =  2.849999999999996
# =======================
# Weight =  2.8000000000000003
#   True input  Pred output  True output         Loss
#         1.00         2.80         3.00       0.0400
#         2.00         5.60         6.00       0.1600
#         3.00         8.40         9.00       0.3600
#         4.00        11.20        12.00       0.6400
#         5.00        14.00        15.00       1.0000
#         6.00        16.80        18.00       1.4400
#         7.00        19.60        21.00       1.9600
#         8.00        22.40        24.00       2.5600
#         9.00        25.20        27.00       3.2400
# MSE =  1.2666666666666635
# =======================
# Weight =  2.9000000000000004
#   True input  Pred output  True output         Loss
#         1.00         2.90         3.00       0.0100
#         2.00         5.80         6.00       0.0400
#         3.00         8.70         9.00       0.0900
#         4.00        11.60        12.00       0.1600
#         5.00        14.50        15.00       0.2500
#         6.00        17.40        18.00       0.3600
#         7.00        20.30        21.00       0.4900
#         8.00        23.20        24.00       0.6400
#         9.00        26.10        27.00       0.8100
# MSE =  0.3166666666666645
# =======================
# Weight =  3.0
#   True input  Pred output  True output         Loss
#         1.00         3.00         3.00       0.0000
#         2.00         6.00         6.00       0.0000
#         3.00         9.00         9.00       0.0000
#         4.00        12.00        12.00       0.0000
#         5.00        15.00        15.00       0.0000
#         6.00        18.00        18.00       0.0000
#         7.00        21.00        21.00       0.0000
#         8.00        24.00        24.00       0.0000
#         9.00        27.00        27.00       0.0000
# MSE =  0.0
# =======================
# Weight =  3.1
#   True input  Pred output  True output         Loss
#         1.00         3.10         3.00       0.0100
#         2.00         6.20         6.00       0.0400
#         3.00         9.30         9.00       0.0900
#         4.00        12.40        12.00       0.1600
#         5.00        15.50        15.00       0.2500
#         6.00        18.60        18.00       0.3600
#         7.00        21.70        21.00       0.4900
#         8.00        24.80        24.00       0.6400
#         9.00        27.90        27.00       0.8100
# MSE =  0.31666666666666743
# =======================
# Weight =  3.2
#   True input  Pred output  True output         Loss
#         1.00         3.20         3.00       0.0400
#         2.00         6.40         6.00       0.1600
#         3.00         9.60         9.00       0.3600
#         4.00        12.80        12.00       0.6400
#         5.00        16.00        15.00       1.0000
#         6.00        19.20        18.00       1.4400
#         7.00        22.40        21.00       1.9600
#         8.00        25.60        24.00       2.5600
#         9.00        28.80        27.00       3.2400
# MSE =  1.2666666666666693
# =======================
# Weight =  3.3000000000000003
#   True input  Pred output  True output         Loss
#         1.00         3.30         3.00       0.0900
#         2.00         6.60         6.00       0.3600
#         3.00         9.90         9.00       0.8100
#         4.00        13.20        12.00       1.4400
#         5.00        16.50        15.00       2.2500
#         6.00        19.80        18.00       3.2400
#         7.00        23.10        21.00       4.4100
#         8.00        26.40        24.00       5.7600
#         9.00        29.70        27.00       7.2900
# MSE =  2.8500000000000036
# =======================
# Weight =  3.4000000000000004
#   True input  Pred output  True output         Loss
#         1.00         3.40         3.00       0.1600
#         2.00         6.80         6.00       0.6400
#         3.00        10.20         9.00       1.4400
#         4.00        13.60        12.00       2.5600
#         5.00        17.00        15.00       4.0000
#         6.00        20.40        18.00       5.7600
#         7.00        23.80        21.00       7.8400
#         8.00        27.20        24.00      10.2400
#         9.00        30.60        27.00      12.9600
# MSE =  5.0666666666666735
# =======================
# Weight =  3.5
#   True input  Pred output  True output         Loss
#         1.00         3.50         3.00       0.2500
#         2.00         7.00         6.00       1.0000
#         3.00        10.50         9.00       2.2500
#         4.00        14.00        12.00       4.0000
#         5.00        17.50        15.00       6.2500
#         6.00        21.00        18.00       9.0000
#         7.00        24.50        21.00      12.2500
#         8.00        28.00        24.00      16.0000
#         9.00        31.50        27.00      20.2500
# MSE =  7.916666666666667
# =======================
# Weight =  3.6
#   True input  Pred output  True output         Loss
#         1.00         3.60         3.00       0.3600
#         2.00         7.20         6.00       1.4400
#         3.00        10.80         9.00       3.2400
#         4.00        14.40        12.00       5.7600
#         5.00        18.00        15.00       9.0000
#         6.00        21.60        18.00      12.9600
#         7.00        25.20        21.00      17.6400
#         8.00        28.80        24.00      23.0400
#         9.00        32.40        27.00      29.1600
# MSE =  11.399999999999999
# =======================
# Weight =  3.7
#   True input  Pred output  True output         Loss
#         1.00         3.70         3.00       0.4900
#         2.00         7.40         6.00       1.9600
#         3.00        11.10         9.00       4.4100
#         4.00        14.80        12.00       7.8400
#         5.00        18.50        15.00      12.2500
#         6.00        22.20        18.00      17.6400
#         7.00        25.90        21.00      24.0100
#         8.00        29.60        24.00      31.3600
#         9.00        33.30        27.00      39.6900
# MSE =  15.51666666666668
# =======================
# Weight =  3.8000000000000003
#   True input  Pred output  True output         Loss
#         1.00         3.80         3.00       0.6400
#         2.00         7.60         6.00       2.5600
#         3.00        11.40         9.00       5.7600
#         4.00        15.20        12.00      10.2400
#         5.00        19.00        15.00      16.0000
#         6.00        22.80        18.00      23.0400
#         7.00        26.60        21.00      31.3600
#         8.00        30.40        24.00      40.9600
#         9.00        34.20        27.00      51.8400
# MSE =  20.266666666666676
# =======================
# Weight =  3.9000000000000004
#   True input  Pred output  True output         Loss
#         1.00         3.90         3.00       0.8100
#         2.00         7.80         6.00       3.2400
#         3.00        11.70         9.00       7.2900
#         4.00        15.60        12.00      12.9600
#         5.00        19.50        15.00      20.2500
#         6.00        23.40        18.00      29.1600
#         7.00        27.30        21.00      39.6900
#         8.00        31.20        24.00      51.8400
#         9.00        35.10        27.00      65.6100
# MSE =  25.650000000000016
# =======================
# Weight =  4.0
#   True input  Pred output  True output         Loss
#         1.00         4.00         3.00       1.0000
#         2.00         8.00         6.00       4.0000
#         3.00        12.00         9.00       9.0000
#         4.00        16.00        12.00      16.0000
#         5.00        20.00        15.00      25.0000
#         6.00        24.00        18.00      36.0000
#         7.00        28.00        21.00      49.0000
#         8.00        32.00        24.00      64.0000
#         9.00        36.00        27.00      81.0000
# MSE =  31.666666666666668
# =======================
# Weight =  4.1000000000000005
#   True input  Pred output  True output         Loss
#         1.00         4.10         3.00       1.2100
#         2.00         8.20         6.00       4.8400
#         3.00        12.30         9.00      10.8900
#         4.00        16.40        12.00      19.3600
#         5.00        20.50        15.00      30.2500
#         6.00        24.60        18.00      43.5600
#         7.00        28.70        21.00      59.2900
#         8.00        32.80        24.00      77.4400
#         9.00        36.90        27.00      98.0100
# MSE =  38.3166666666667
# =======================
# Weight =  4.2
#   True input  Pred output  True output         Loss
#         1.00         4.20         3.00       1.4400
#         2.00         8.40         6.00       5.7600
#         3.00        12.60         9.00      12.9600
#         4.00        16.80        12.00      23.0400
#         5.00        21.00        15.00      36.0000
#         6.00        25.20        18.00      51.8400
#         7.00        29.40        21.00      70.5600
#         8.00        33.60        24.00      92.1600
#         9.00        37.80        27.00     116.6400
# MSE =  45.60000000000002
# =======================
# Weight =  4.3
#   True input  Pred output  True output         Loss
#         1.00         4.30         3.00       1.6900
#         2.00         8.60         6.00       6.7600
#         3.00        12.90         9.00      15.2100
#         4.00        17.20        12.00      27.0400
#         5.00        21.50        15.00      42.2500
#         6.00        25.80        18.00      60.8400
#         7.00        30.10        21.00      82.8100
#         8.00        34.40        24.00     108.1600
#         9.00        38.70        27.00     136.8900
# MSE =  53.51666666666664
# =======================
# Weight =  4.4
#   True input  Pred output  True output         Loss
#         1.00         4.40         3.00       1.9600
#         2.00         8.80         6.00       7.8400
#         3.00        13.20         9.00      17.6400
#         4.00        17.60        12.00      31.3600
#         5.00        22.00        15.00      49.0000
#         6.00        26.40        18.00      70.5600
#         7.00        30.80        21.00      96.0400
#         8.00        35.20        24.00     125.4400
#         9.00        39.60        27.00     158.7600
# MSE =  62.06666666666669
# =======================
# Weight =  4.5
#   True input  Pred output  True output         Loss
#         1.00         4.50         3.00       2.2500
#         2.00         9.00         6.00       9.0000
#         3.00        13.50         9.00      20.2500
#         4.00        18.00        12.00      36.0000
#         5.00        22.50        15.00      56.2500
#         6.00        27.00        18.00      81.0000
#         7.00        31.50        21.00     110.2500
#         8.00        36.00        24.00     144.0000
#         9.00        40.50        27.00     182.2500
# MSE =  71.25
# =======================
# Weight =  4.6000000000000005
#   True input  Pred output  True output         Loss
#         1.00         4.60         3.00       2.5600
#         2.00         9.20         6.00      10.2400
#         3.00        13.80         9.00      23.0400
#         4.00        18.40        12.00      40.9600
#         5.00        23.00        15.00      64.0000
#         6.00        27.60        18.00      92.1600
#         7.00        32.20        21.00     125.4400
#         8.00        36.80        24.00     163.8400
#         9.00        41.40        27.00     207.3600
# MSE =  81.06666666666672
# =======================
# Weight =  4.7
#   True input  Pred output  True output         Loss
#         1.00         4.70         3.00       2.8900
#         2.00         9.40         6.00      11.5600
#         3.00        14.10         9.00      26.0100
#         4.00        18.80        12.00      46.2400
#         5.00        23.50        15.00      72.2500
#         6.00        28.20        18.00     104.0400
#         7.00        32.90        21.00     141.6100
#         8.00        37.60        24.00     184.9600
#         9.00        42.30        27.00     234.0900
# MSE =  91.51666666666671
# =======================
# Weight =  4.800000000000001
#   True input  Pred output  True output         Loss
#         1.00         4.80         3.00       3.2400
#         2.00         9.60         6.00      12.9600
#         3.00        14.40         9.00      29.1600
#         4.00        19.20        12.00      51.8400
#         5.00        24.00        15.00      81.0000
#         6.00        28.80        18.00     116.6400
#         7.00        33.60        21.00     158.7600
#         8.00        38.40        24.00     207.3600
#         9.00        43.20        27.00     262.4400
# MSE =  102.60000000000008
# =======================
# Weight =  4.9
#   True input  Pred output  True output         Loss
#         1.00         4.90         3.00       3.6100
#         2.00         9.80         6.00      14.4400
#         3.00        14.70         9.00      32.4900
#         4.00        19.60        12.00      57.7600
#         5.00        24.50        15.00      90.2500
#         6.00        29.40        18.00     129.9600
#         7.00        34.30        21.00     176.8900
#         8.00        39.20        24.00     231.0400
#         9.00        44.10        27.00     292.4100
# MSE =  114.3166666666667
# =======================
# Weight =  5.0
#   True input  Pred output  True output         Loss
#         1.00         5.00         3.00       4.0000
#         2.00        10.00         6.00      16.0000
#         3.00        15.00         9.00      36.0000
#         4.00        20.00        12.00      64.0000
#         5.00        25.00        15.00     100.0000
#         6.00        30.00        18.00     144.0000
#         7.00        35.00        21.00     196.0000
#         8.00        40.00        24.00     256.0000
#         9.00        45.00        27.00     324.0000
# MSE =  126.66666666666667

# %% [markdown]
# ### Step 3: Plotting and find the opt weight visually:

# %%
# Plot
plt.plot(weight_list, mse_list)
plt.xlabel('Weight')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
